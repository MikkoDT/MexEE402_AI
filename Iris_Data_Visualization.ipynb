# %% [markdown]
# <a href="https://colab.research.google.com/github/MikkoDT/MexEE402_AI/blob/main/Iris_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Step 1: Setting up Google Colab**
#
#
# *   Use !pip install then the library needed to make sure you can use the library

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %% [markdown]
# # **Step 2: Importing the Necessary Libraries**
#
#
# *   Pandas: For handling our data in tabular format efficiently.
# *   Seaborn: For creating beautiful statistical visualizations.
# *   Matplotlib: For additional customization of our plots.
# *   Plotly: For creating interactive and dynamic plots.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # **Step 3: Loading the Dataset**
#
# *   Load the Iris dataset using seaborn’s built-in function and inspect its structure before visualization.

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# # **Step 4: Exploring the Dataset**

# %%
# Print the first 5 rows of the DataFrame
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Print information about the DataFrame
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Print statistical summary of the DataFrame
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # **Step 5: Visualizing the Dataset**
#
#
# Use a pair plot to visualize relationships between features and uncover patterns in the dataset.

# %%
# Create a pair plot of the measurements, color-coded by species

sns.pairplot(iris, hue='species')

plt.show()

# %% [markdown]
# **Pair plot** shows scatterplots and histograms for all features, with color-coding by species to highlight differences and separations between them.
#
#
#
# *   **Histograms (Diagonal):** Show feature distributions; e.g., sepal_width ~ normal, petal_length/width ~ bimodal.
#
# *   **Scatterplots (Off-diagonal):** Show feature relationships; petal_length vs. petal_width shows strong positive correlation.
#
# *   **Species Separation:** Color-coding reveals Iris-setosa is clearly distinct; versicolor and virginica overlap.
#
# *   **Outliers/Overlaps:** Some versicolor points overlap with virginica, hinting at misclassification.

# %% [markdown]
# # **Step 6: Creating a Heatmap**
# **Heatmap** is another excellent visualization to understand the correlation between different numerical features in the dataset.
#
#
# Correlation values range from -1 to +1
#
#
# *   +1 → perfect positive relationship (as one increases, the other increases)
#
# *   -1 → perfect negative relationship (as one increases, the other decreases)
#
# *   0 → no linear relationship
#
# The heatmap colors make it easy to spot:
# *   Darker/red tones → strong positive correlation
#
# *   Darker/blue tones → strong negative correlation
#
# *   Lighter/neutral → weak or no correlation

# %%
plt.figure(figsize=(10,7))

# Use only numeric columns for correlation
sns.heatmap(iris.drop('species', axis=1).corr(), annot=True, cmap='coolwarm')

plt.title('Heatmap for the Dataset')
plt.show()

# %% [markdown]
# # **Step 7: Creating Distribution Plots**
# Interpreting the Distribution Plots:
#
#
# *   **Sepal Length:** Setosa has shorter sepals (4.5–5.5 cm), while Versicolor and Virginica are longer but overlap.
#
# *   **Sepal Width:** Setosa has larger widths; Versicolor and
# Virginica overlap heavily, making this feature less useful.
#
# *   **Petal Length:** Clear separation — Setosa < Versicolor < Virginica. Strong distinguishing feature.
#
# *   **Petal Width:** Similar to petal length, clear separation among species.

# %%
for column in iris.columns[:-1]:  # excluding the 'species' column
    sns.displot(iris, x=column, hue='species', kde=True)
    plt.title(f'Distribution for {column}')
    plt.show()

# %% [markdown]
# # **Step 8: Creating a Box Plot**
# **Box plots,** also known as box-and-whisker plots, are helpful for visualizing the variance in the data and identifying potential outliers.
#
# **Outliers** are data points that differ significantly from the majority of the data.
#
# 🔹 They are unusually high or low values compared to the rest of the dataset.
#
# 🔹 Outliers can appear due to measurement errors, variability in the data, or rare events.
#
# 🔹 In plots (like boxplots), outliers are often shown as individual points outside the "whiskers" (the typical range of the data).

# %%
sns.boxplot(data=iris, x='species', y='sepal_length', palette="Set2")
plt.title('Box Plot of Sepal Length for Each Species')
plt.show()
# Out:
# /tmp/ipython-input-1022347011.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris, x='species', y='sepal_length', palette="Set2")

# %% [markdown]
# Interpreting the Box Plot:
#
#
# *   **Setosa:** Median ≈ 5.0 cm; range 4.3–5.8 cm; no outliers.
#
# *   **Versicolor:** Median ≈ 5.9 cm; range 5.0–7.0 cm; some outliers present.
#
# *   **Virginica:** Median ≈ 6.5 cm; range 5.8–7.7 cm; few outliers present.

# %% [markdown]
# # **Step 9: Creating Interactive Plots**

# %%
fig = px.scatter(iris, x='sepal_width', y='sepal_length', color='species')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Interpreting the Interactive Scatter Plot:
#
# *   **Setosa (blue):** Clear positive correlation – wider sepals → longer sepals.
#
# *   **Versicolor (orange):** More scattered, weak positive trend.
#
# *   **Virginica (green):** Scattered, weak correlation like Versicolor.
#
# *   **Interactive Advantage:** Hovering shows exact sepal length/width for deeper exploration.

# %% [markdown]
# # **Step 10: Analyzing the Visualizations**
#
# **Key Insights from Visualizations:**
#
#
#
# *   **Iris Species:** Three types – Setosa, Versicolor, Virginica.
#
# *   **Feature Distribution:** Petal length/width best separate species (Setosa = small, Virginica = large).
#
# *   **Feature Correlation:** Petal length and width are strongly correlated.
#
# *   **Sepal Length:** Virginica > Versicolor > Setosa, no major outliers.
#
# *   **Sepal Width vs Length:** Setosa shows clear positive trend; others weaker.
#
# *   **Interactive Plotting:** Enables dynamic exploration and viewing exact values.
