# %% [markdown]
# <a href="https://colab.research.google.com/github/MikkoDT/MexEE402_AI/blob/main/Visualizing_Time_Series_Data_with_Line_Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('temperature_data.csv')

# %%
plt.plot(df['Date'], df['Temperature'])
plt.title('Daily Temperature Over a Month')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.xticks(rotation=45) # Rotates the x-axis labels by 45 degrees
plt.tight_layout() # Adjusts the layout so everything fits in the figure
plt.show()
