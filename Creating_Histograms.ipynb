# %% [markdown]
# <a href="https://colab.research.google.com/github/MikkoDT/MexEE402_AI/blob/main/Creating_Histograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('scores.csv')

# %%
# Create a histogram of exam scores with 10 bins (adjust bins as needed)
plt.hist(data['scores'], bins=10, edgecolor='black')
plt.title('Distribution of Final Exam Scores')
plt.xlabel('Scores')
plt.ylabel('Number of Students')
plt.show()
